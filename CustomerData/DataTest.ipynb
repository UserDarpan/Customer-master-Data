# %% [markdown]
# Data Cleaning

# %%
import pandas as pd

# Load the Excel sheet
file_path = 'Small_test_data.csv'  # Replace with your actual file path
sheet_name = 'Sheet2'  # Update if your sheet has a different name
df = pd.read_csv(file_path)

# List of address columns
address_columns = ['billingstreet', 'billingcity', 'billingstate', 'billingpostalcode', 'billingcountry']

# Clean each column by removing extra spaces
for column in address_columns:
    if column in df.columns:
        df[column] = df[column].astype(str).str.strip()  # Convert to string if needed and strip spaces

# Save the cleaned data to a new Excel file
cleaned_file_path = 'cleaned_test_data.csv'
df.to_csv(cleaned_file_path, index=False)

print(f"Data cleaning complete. Cleaned data saved to {cleaned_file_path}")
# Out:
# Data cleaning complete. Cleaned data saved to cleaned_test_data.csv

# %%
import pandas as pd
from chromadb import Client
from sentence_transformers import SentenceTransformer

# Load your data
df = pd.read_csv("cleaned_test_data.csv")

# Initialize embedding model and ChromaDB client
model = SentenceTransformer('all-MiniLM-L6-v2')  # Use an appropriate model
client = Client()

# Create or access a collection for address fields
collection = client.get_or_create_collection(name="address_fields_test")

# Embed and insert each field into ChromaDB with field-specific metadata
for _, row in df.iterrows():
    metadata = {
        "street": row["billingstreet"],
        "city": row["billingcity"],
        "state": row["billingstate"],
        "postal_code": row["billingpostalcode"],
        "country": row["billingcountry"]
    }
    
    # Embed each field separately
    for field, value in metadata.items():
        if value:  # Ensure field is not empty
            embedding = model.encode(value).tolist()
            
            # Each record needs a unique ID in ChromaDB
            unique_id = f"{field}_{_}"
            
            # Use the correct ChromaDB syntax to add the embedding with metadata
            collection.add(
                documents=[value],
                metadatas=[metadata],
                ids=[unique_id],
                embeddings=[embedding]
            )

# Query by individual fields
query_value = "500 Clipper Dr"  # For example, querying with city name
query_embedding = model.encode(query_value).tolist()
results = collection.query(query_embeddings=[query_embedding], n_results=1)

# Format the output by fetching the correct field values
# for result in results['documents']:
#     print(results)

    # print(f"Street: {result['metadata'].get('street', 'N/A')}")
    # print(f"City: {result['metadata'].get('city', 'N/A')}")
    # print(f"State: {result['metadata'].get('state', 'N/A')}")
    # print(f"Postal Code: {result['metadata'].get('postal_code', 'N/A')}")
    # print(f"Country: {result['metadata'].get('country', 'N/A')}")
for metadata in results['metadatas']:
    metadata_entry = metadata[0]  # Access the first (and only) item in the nested list
    print(f"Street: {metadata_entry.get('street', 'N/A')}")
    print(f"City: {metadata_entry.get('city', 'N/A')}")
    print(f"State: {metadata_entry.get('state', 'N/A')}")
    print(f"Postal Code: {metadata_entry.get('postal_code', 'N/A')}")
    print(f"Country: {metadata_entry.get('country', 'N/A')}")
# Out:
# Add of existing embedding ID: street_0
# Insert of existing embedding ID: street_0
# Add of existing embedding ID: city_0
# Insert of existing embedding ID: city_0
# Add of existing embedding ID: state_0
# Insert of existing embedding ID: state_0
# Add of existing embedding ID: postal_code_0
# Insert of existing embedding ID: postal_code_0
# Add of existing embedding ID: country_0
# Insert of existing embedding ID: country_0
# Add of existing embedding ID: street_1
# Insert of existing embedding ID: street_1
# Add of existing embedding ID: city_1
# Insert of existing embedding ID: city_1
# Add of existing embedding ID: state_1
# Insert of existing embedding ID: state_1
# Add of existing embedding ID: postal_code_1
# Insert of existing embedding ID: postal_code_1
# Add of existing embedding ID: country_1
# Insert of existing embedding ID: country_1
# Add of existing embedding ID: street_2
# Insert of existing embedding ID: street_2
# Add of existing embedding ID: city_2
# Insert of existing embedding ID: city_2
# Add of existing embedding ID: state_2
# Insert of existing embedding ID: state_2
# Add of existing embedding ID: postal_code_2
# Insert of existing embedding ID: postal_code_2
# Add of existing embedding ID: country_2
# Insert of existing embedding ID: country_2
# Add of existing embedding ID: street_3
# Insert of existing embedding ID: street_3
# Add of existing embedding ID: city_3
# Insert of existing embedding ID: city_3
# Add of existing embedding ID: state_3
# Insert of existing embedding ID: state_3
# Add of existing embedding ID: postal_code_3
# Insert of existing embedding ID: postal_code_3
# Add of existing embedding ID: country_3
# Insert of existing embedding ID: country_3
# Add of existing embedding ID: street_4
# Insert of existing embedding ID: street_4
# Add of existing embedding ID: city_4
# Insert of existing embedding ID: city_4
# Add of existing embedding ID: state_4
# Insert of existing embedding ID: state_4
# Add of existing embedding ID: postal_code_4
# Insert of existing embedding ID: postal_code_4
# Add of existing embedding ID: country_4
# Insert of existing embedding ID: country_4
# Add of existing embedding ID: street_5
# Insert of existing embedding ID: street_5
# Add of existing embedding ID: city_5
# Insert of existing embedding ID: city_5
# Add of existing embedding ID: state_5
# Insert of existing embedding ID: state_5
# Add of existing embedding ID: postal_code_5
# Insert of existing embedding ID: postal_code_5
# Add of existing embedding ID: country_5
# Insert of existing embedding ID: country_5
# Add of existing embedding ID: street_6
# Insert of existing embedding ID: street_6
# Add of existing embedding ID: city_6
# Insert of existing embedding ID: city_6
# Add of existing embedding ID: state_6
# Insert of existing embedding ID: state_6
# Add of existing embedding ID: postal_code_6
# Insert of existing embedding ID: postal_code_6
# Add of existing embedding ID: country_6
# Insert of existing embedding ID: country_6
# Add of existing embedding ID: street_7
# Insert of existing embedding ID: street_7
# Add of existing embedding ID: city_7
# Insert of existing embedding ID: city_7
# Add of existing embedding ID: state_7
# Insert of existing embedding ID: state_7
# Add of existing embedding ID: postal_code_7
# Insert of existing embedding ID: postal_code_7
# Add of existing embedding ID: country_7
# Insert of existing embedding ID: country_7
# Add of existing embedding ID: street_8
# Insert of existing embedding ID: street_8
# Add of existing embedding ID: city_8
# Insert of existing embedding ID: city_8
# Add of existing embedding ID: state_8
# Insert of existing embedding ID: state_8
# Add of existing embedding ID: postal_code_8
# Insert of existing embedding ID: postal_code_8
# Add of existing embedding ID: country_8
# Insert of existing embedding ID: country_8
# Add of existing embedding ID: street_9
# Insert of existing embedding ID: street_9
# Add of existing embedding ID: city_9
# Insert of existing embedding ID: city_9
# Add of existing embedding ID: state_9
# Insert of existing embedding ID: state_9
# Add of existing embedding ID: postal_code_9
# Insert of existing embedding ID: postal_code_9
# Add of existing embedding ID: country_9
# Insert of existing embedding ID: country_9
# Add of existing embedding ID: street_10
# Insert of existing embedding ID: street_10
# Add of existing embedding ID: city_10
# Insert of existing embedding ID: city_10
# Add of existing embedding ID: state_10
# Insert of existing embedding ID: state_10
# Add of existing embedding ID: postal_code_10
# Insert of existing embedding ID: postal_code_10
# Add of existing embedding ID: country_10
# Insert of existing embedding ID: country_10
# Add of existing embedding ID: street_11
# Insert of existing embedding ID: street_11
# Add of existing embedding ID: city_11
# Insert of existing embedding ID: city_11
# Add of existing embedding ID: state_11
# Insert of existing embedding ID: state_11
# Add of existing embedding ID: postal_code_11
# Insert of existing embedding ID: postal_code_11
# Add of existing embedding ID: country_11
# Insert of existing embedding ID: country_11
# Add of existing embedding ID: street_12
# Insert of existing embedding ID: street_12
# Add of existing embedding ID: city_12
# Insert of existing embedding ID: city_12
# Add of existing embedding ID: state_12
# Insert of existing embedding ID: state_12
# Add of existing embedding ID: postal_code_12
# Insert of existing embedding ID: postal_code_12
# Add of existing embedding ID: country_12
# Insert of existing embedding ID: country_12
# Add of existing embedding ID: street_13
# Insert of existing embedding ID: street_13
# Add of existing embedding ID: city_13
# Insert of existing embedding ID: city_13
# Add of existing embedding ID: state_13
# Insert of existing embedding ID: state_13
# Add of existing embedding ID: postal_code_13
# Insert of existing embedding ID: postal_code_13
# Add of existing embedding ID: country_13
# Insert of existing embedding ID: country_13
# Add of existing embedding ID: street_14
# Insert of existing embedding ID: street_14
# Add of existing embedding ID: city_14
# Insert of existing embedding ID: city_14
# Add of existing embedding ID: state_14
# Insert of existing embedding ID: state_14
# Add of existing embedding ID: postal_code_14
# Insert of existing embedding ID: postal_code_14
# Add of existing embedding ID: country_14
# Insert of existing embedding ID: country_14
# Add of existing embedding ID: street_15
# Insert of existing embedding ID: street_15
# Add of existing embedding ID: city_15
# Insert of existing embedding ID: city_15
# Add of existing embedding ID: state_15
# Insert of existing embedding ID: state_15
# Add of existing embedding ID: postal_code_15
# Insert of existing embedding ID: postal_code_15
# Add of existing embedding ID: country_15
# Insert of existing embedding ID: country_15
# Add of existing embedding ID: street_16
# Insert of existing embedding ID: street_16
# Add of existing embedding ID: city_16
# Insert of existing embedding ID: city_16
# Add of existing embedding ID: state_16
# Insert of existing embedding ID: state_16
# Add of existing embedding ID: postal_code_16
# Insert of existing embedding ID: postal_code_16
# Add of existing embedding ID: country_16
# Insert of existing embedding ID: country_16
# Add of existing embedding ID: street_17
# Insert of existing embedding ID: street_17
# Add of existing embedding ID: city_17
# Insert of existing embedding ID: city_17
# Add of existing embedding ID: state_17
# Insert of existing embedding ID: state_17
# Add of existing embedding ID: postal_code_17
# Insert of existing embedding ID: postal_code_17
# Add of existing embedding ID: country_17
# Insert of existing embedding ID: country_17
# Add of existing embedding ID: street_18
# Insert of existing embedding ID: street_18
# Add of existing embedding ID: city_18
# Insert of existing embedding ID: city_18
# Add of existing embedding ID: state_18
# Insert of existing embedding ID: state_18
# Add of existing embedding ID: postal_code_18
# Insert of existing embedding ID: postal_code_18
# Add of existing embedding ID: country_18
# Insert of existing embedding ID: country_18
# Add of existing embedding ID: street_19
# Insert of existing embedding ID: street_19
# Add of existing embedding ID: city_19
# Insert of existing embedding ID: city_19
# Add of existing embedding ID: state_19
# Insert of existing embedding ID: state_19
# Add of existing embedding ID: postal_code_19
# Insert of existing embedding ID: postal_code_19
# Add of existing embedding ID: country_19
# Insert of existing embedding ID: country_19
# Add of existing embedding ID: street_20
# Insert of existing embedding ID: street_20
# Add of existing embedding ID: city_20
# Insert of existing embedding ID: city_20
# Add of existing embedding ID: state_20
# Insert of existing embedding ID: state_20
# Add of existing embedding ID: postal_code_20
# Insert of existing embedding ID: postal_code_20
# Add of existing embedding ID: country_20
# Insert of existing embedding ID: country_20
# Add of existing embedding ID: street_21
# Insert of existing embedding ID: street_21
# Add of existing embedding ID: city_21
# Insert of existing embedding ID: city_21
# Add of existing embedding ID: state_21
# Insert of existing embedding ID: state_21
# Add of existing embedding ID: postal_code_21
# Insert of existing embedding ID: postal_code_21
# Add of existing embedding ID: country_21
# Insert of existing embedding ID: country_21
# Add of existing embedding ID: street_22
# Insert of existing embedding ID: street_22
# Add of existing embedding ID: city_22
# Insert of existing embedding ID: city_22
# Add of existing embedding ID: state_22
# Insert of existing embedding ID: state_22
# Add of existing embedding ID: postal_code_22
# Insert of existing embedding ID: postal_code_22
# Add of existing embedding ID: country_22
# Insert of existing embedding ID: country_22
# Street: 500 Clipper Dr
# City: Belmont
# State: California
# Postal Code: 94002-4169
# Country: United States

# %%
# Query by individual fields
query_value = "Pfizer700 Chesapeake Dr"  # For example, querying with city name
query_embedding = model.encode(query_value).tolist()
results = collection.query(query_embeddings=[query_embedding], n_results=1)

for metadata in results['metadatas']:
    metadata_entry = metadata[0]  # Access the first (and only) item in the nested list
    print(f"Street: {metadata_entry.get('street', 'N/A')}")
    print(f"City: {metadata_entry.get('city', 'N/A')}")
    print(f"State: {metadata_entry.get('state', 'N/A')}")
    print(f"Postal Code: {metadata_entry.get('postal_code', 'N/A')}")
    print(f"Country: {metadata_entry.get('country', 'N/A')}")
# Out:
# Street: 700 Chesapeake Dr
# City: Redwood City
# State: California
# Postal Code: 94063-4731
# Country: United States
